# %% [markdown]
# #### This code file is same as of 1 ANN training using iterative feature selection process with base model being on common features.
#
# #### Changes made are in this file considers all five output columns for generating a final output binary value. Other hyperparameters too ar changed

# %%
#Import all the necessary libraries
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as nm
nm.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
# for later versions:
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

#os.environ['TF_DETERMINISTIC_OPS'] = '1'
#os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# Check GPU availability
print("GPU Available:", tf.config.list_physical_devices("GPU"))

# Check CPU availability
print("CPU Available:", tf.config.list_physical_devices("CPU"))

import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler 
from keras.models import Sequential #importing Sequential Model.It uses tensorflow backend and you need to have tensorflow setup. 
from keras.layers import Dense #Importing default dense layer
from sklearn.utils import shuffle
from keras.regularizers import l1, l2
from keras.optimizers import SGD
from sklearn.metrics import accuracy_score


path_dir='C:/Users/subhi/AMNS_Second_phase_ANN_model/Datasets/'
filename1='Common_Data.xlsx'
filename2='Intersection_Data.xlsx'
#Access all the necessary variables and datasets
# %store -r common_data 
# %store -r random_forest_data
random_forest_data.shape #161 statistical features and one output column
# Using the common_data dataframe created in 1_ANN_Model_on_common_features
#Usibg the appended_data dataframe created in Random_Forest_Code 
common_data
# Out:
# GPU Available: []
# CPU Available: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
#      NARROWFACESECONDARYCOOLINGWATERPRESSUREACTUALMEAN  \
# 0                                             4.925862
# 1                                             4.915455
# 2                                             5.482414
# 3                                             5.471203
# 4                                             5.081299
# ..                                                 ...
# 586                                           2.140476
# 587                                           2.098624
# 588                                           2.097216
# 589                                           2.091311
# 590                                           2.086576
#
#      MOLDBROADFACE1INLETOUTLETWATERTEMP.DELTAMEAN  STEELLEVELINMOLD-SETMEAN  \
# 0                                        4.000000                 80.103621
# 1                                        4.000000                 80.104899
# 2                                        4.000000                 80.106667
# 3                                        4.000000                 80.108861
# 4                                        4.000000                 80.110282
# ..                                            ...                       ...
# 586                                      7.994048                 80.108333
# 587                                      8.052910                 80.107513
# 588                                      7.407216                 80.109175
# 589                                      7.121359                 80.106019
# 590                                      7.065217                 80.105435
#
#      SEG0BSECONDARYCOOLINGWATERPRESSUREACTUALMEAN  \
# 0                                        1.177759
# 1                                        1.170657
# 2                                        1.239828
# 3                                        1.240000
# 4                                        1.190000
# ..                                            ...
# 586                                      0.789524
# 587                                      0.334974
# 588                                      0.544330
# 589                                      0.722087
# 590                                      0.859620
#
#      SEG9+10+11+12BOTTOMSECONDARYCOOLINGWATERFLOWACTUALMEAN  LIQUIDUSTEMPMEAN  \
# 0                                           190.958678             1521.40790
# 1                                           195.140556             1521.76000
# 2                                           191.464138             1521.26000
# 3                                           187.756139             1521.74000
# 4                                           188.373955             1521.41000
# ..                                                 ...                    ...
# 586                                         213.972321             1514.56430
# 587                                         204.833228             1515.94260
# 588                                         213.607887             1512.56210
# 589                                          31.653689             1512.88320
# 590                                          31.550598             1512.30945
#
#      NARROWFACE1WATERFLOWMEAN  TUNDISHWEIGHTMEAN  OUTPUT
# 0                  461.735632          23.854885       1
# 1                  461.954545          23.548081       1
# 2                  461.534483          24.320115       0
# 3                  461.892405          24.275696       0
# 4                  462.028249          24.563785       1
# ..                        ...                ...     ...
# 586                452.720238          23.541369       0
# 587                443.820106          27.779471       1
# 588                452.283505          22.814948       1
# 589                452.150485          24.742087       1
# 590                452.614130          24.789022       1
#
# [591 rows x 9 columns]

# %% [markdown]
# ### Training the base model

# %%
common_data = shuffle(common_data, random_state=42)
#Defining train and test sizes
total_length= common_data.shape[0]
train_size=int(common_data.shape[0]*0.8)
test_size=common_data.shape[0]-train_size

# First converting dataframe series into numpy array and setting the datatype as float32 for all data
# In second step converting all 1D array into 2D array
train_X=common_data.iloc[:,:-1][0:train_size].to_numpy().astype(nm.float32) #2D array

train_Y=common_data['OUTPUT'][0:train_size].to_numpy().astype(nm.float32) #1D array
train_Y=nm.reshape(train_Y,(train_Y.shape[0],1)) # 2D array

test_X=common_data.iloc[:,:-1][train_size:].to_numpy().astype(nm.float32) #2D array

test_Y=common_data['OUTPUT'][train_size:].to_numpy().astype(nm.float32) #1D array
test_Y=nm.reshape(test_Y,(test_Y.shape[0],1)) # 2D array

print('Dimension of training data',train_X.shape)
print('Dimension of testing data',test_X.shape)

#print(train_X)
print(type(train_X))
print(train_Y.shape)
test_Y.shape #2-D array
#train_Y
# Out:
# Dimension of training data (472, 8)
# Dimension of testing data (119, 8)
# <class 'numpy.ndarray'>
# (472, 1)
# (119, 1)

# %%
#scaler=MinMaxScaler(feature_range=(0,1)) # scaler object
scaler=RobustScaler()
# First fit the scaler with your training data.
# It will find those parameters using which it is going to scale.
# Then transform any data you want.

train_X=scaler.fit_transform(train_X) 

# Since it has scaled  the data as per the parameters it learnt during training data.
# So it will require 2D array/similiar dimension as of training data.
# So testing data should be a 2D array.
# Testing data only need to be transformed on the basis of the parameters learnt using fit function on training data.

test_X=scaler.transform(test_X) #Scaling the training data and using the same parameters for testing data
#test
#train_X[:]

# %%
#Creating a Model
print('Total No of features',len(train_X[0,:])) #No of features
base_model=Sequential() 

base_model.add(Dense(50,input_dim=len(train_X[0,:]),activation='relu',kernel_regularizer=l1(0.01))) # one hidden layer
base_model.add(Dense(1,activation='sigmoid',kernel_regularizer=l1(0.01))) #output layer
        
base_model.summary()
# Out:
# Total No of features 8
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 50)                450
#
#  dense_9 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.compile(optimizer='_' , loss='_' , metrics=['accuracy'])
base_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#Fitting the training data
#base_model.fit(training data input, training data output, batch_size=_,validation_data=(x_test,y_test))
base_model.fit(train_X,train_Y,epochs=150,batch_size=len(train_X),validation_data=(test_X,test_Y))

# Epochs is number of times i want to do forward and backward propogation.
# batch size is used for update the weights in mini batches. The default back size is 32.
# Validation data : accuracy looking like on validation data after every epoch, you can give test data here too. 
#The loss will be reduced due to backpropgation through time.

#Add regularization or increase number of epochs for better accuracy.
# Out:
# Epoch 1/150
# 95/95 [==============================] - 1s 4ms/step - loss: 12.2333 - accuracy: 0.5297 - val_loss: 2.3785 - val_accuracy: 0.5630
# Epoch 2/150
# 95/95 [==============================] - 0s 3ms/step - loss: 1.3297 - accuracy: 0.6250 - val_loss: 1.1491 - val_accuracy: 0.6303
# Epoch 3/150
# 95/95 [==============================] - 0s 2ms/step - loss: 1.1983 - accuracy: 0.6653 - val_loss: 1.2813 - val_accuracy: 0.5630
# Epoch 4/150
# 95/95 [==============================] - 0s 2ms/step - loss: 1.2659 - accuracy: 0.6737 - val_loss: 0.9863 - val_accuracy: 0.6218
# Epoch 5/150
# 95/95 [==============================] - 0s 2ms/step - loss: 1.1331 - accuracy: 0.7013 - val_loss: 1.4255 - val_accuracy: 0.6218
# Epoch 6/150
# 95/95 [==============================] - 0s 2ms/step - loss: 1.2191 - accuracy: 0.6864 - val_loss: 0.9275 - val_accuracy: 0.5966
# Epoch 7/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9354 - accuracy: 0.6864 - val_loss: 0.8716 - val_accuracy: 0.6387
# Epoch 8/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8981 - accuracy: 0.6886 - val_loss: 0.9814 - val_accuracy: 0.6218
# Epoch 9/150
# 95/95 [==============================] - 0s 3ms/step - loss: 1.0745 - accuracy: 0.6928 - val_loss: 0.8398 - val_accuracy: 0.6639
# Epoch 10/150
# 95/95 [==============================] - 0s 2ms/step - loss: 1.0574 - accuracy: 0.6843 - val_loss: 0.8860 - val_accuracy: 0.6050
# Epoch 11/150
# 95/95 [==============================] - 0s 2ms/step - loss: 1.1603 - accuracy: 0.6674 - val_loss: 0.8956 - val_accuracy: 0.5882
# Epoch 12/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.9290 - accuracy: 0.6758 - val_loss: 0.8583 - val_accuracy: 0.5882
# Epoch 13/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.9808 - accuracy: 0.6695 - val_loss: 1.0673 - val_accuracy: 0.6218
# Epoch 14/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8759 - accuracy: 0.6716 - val_loss: 0.8285 - val_accuracy: 0.6050
# Epoch 15/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9468 - accuracy: 0.6568 - val_loss: 0.9526 - val_accuracy: 0.6134
# Epoch 16/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9760 - accuracy: 0.6441 - val_loss: 0.8272 - val_accuracy: 0.6471
# Epoch 17/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9287 - accuracy: 0.6483 - val_loss: 0.8485 - val_accuracy: 0.6218
# Epoch 18/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9183 - accuracy: 0.6653 - val_loss: 1.1375 - val_accuracy: 0.6303
# Epoch 19/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8889 - accuracy: 0.6695 - val_loss: 0.8102 - val_accuracy: 0.6471
# Epoch 20/150
# 95/95 [==============================] - 1s 6ms/step - loss: 0.8655 - accuracy: 0.6653 - val_loss: 0.8167 - val_accuracy: 0.6134
# Epoch 21/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.9065 - accuracy: 0.6483 - val_loss: 0.7976 - val_accuracy: 0.5966
# Epoch 22/150
# 95/95 [==============================] - 0s 3ms/step - loss: 1.0583 - accuracy: 0.6674 - val_loss: 1.2315 - val_accuracy: 0.5966
# Epoch 23/150
# 95/95 [==============================] - 0s 3ms/step - loss: 1.0611 - accuracy: 0.6419 - val_loss: 1.2489 - val_accuracy: 0.6050
# Epoch 24/150
# 95/95 [==============================] - 0s 3ms/step - loss: 1.1940 - accuracy: 0.6483 - val_loss: 0.8476 - val_accuracy: 0.6303
# Epoch 25/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7964 - accuracy: 0.6568 - val_loss: 0.8791 - val_accuracy: 0.6218
# Epoch 26/150
# 95/95 [==============================] - 0s 3ms/step - loss: 1.0861 - accuracy: 0.6462 - val_loss: 0.8950 - val_accuracy: 0.6218
# Epoch 27/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9393 - accuracy: 0.6419 - val_loss: 0.8090 - val_accuracy: 0.6134
# Epoch 28/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.8834 - accuracy: 0.6483 - val_loss: 0.9095 - val_accuracy: 0.6134
# Epoch 29/150
# 95/95 [==============================] - 1s 7ms/step - loss: 0.9712 - accuracy: 0.6483 - val_loss: 0.9640 - val_accuracy: 0.5798
# Epoch 30/150
# 95/95 [==============================] - 0s 5ms/step - loss: 0.8174 - accuracy: 0.6462 - val_loss: 0.8396 - val_accuracy: 0.5798
# Epoch 31/150
# 95/95 [==============================] - 1s 6ms/step - loss: 0.8732 - accuracy: 0.6568 - val_loss: 0.9466 - val_accuracy: 0.6134
# Epoch 32/150
# 95/95 [==============================] - 1s 7ms/step - loss: 0.9046 - accuracy: 0.6525 - val_loss: 0.8057 - val_accuracy: 0.5882
# Epoch 33/150
# 95/95 [==============================] - 1s 7ms/step - loss: 0.8663 - accuracy: 0.6653 - val_loss: 0.8034 - val_accuracy: 0.5882
# Epoch 34/150
# 95/95 [==============================] - 1s 10ms/step - loss: 0.8240 - accuracy: 0.6589 - val_loss: 0.7900 - val_accuracy: 0.5882
# Epoch 35/150
# 95/95 [==============================] - 0s 5ms/step - loss: 0.9184 - accuracy: 0.6441 - val_loss: 0.7802 - val_accuracy: 0.6218
# Epoch 36/150
# 95/95 [==============================] - 0s 3ms/step - loss: 1.0729 - accuracy: 0.6483 - val_loss: 0.8812 - val_accuracy: 0.6134
# Epoch 37/150
# 95/95 [==============================] - 0s 5ms/step - loss: 0.8414 - accuracy: 0.6631 - val_loss: 0.9436 - val_accuracy: 0.6050
# Epoch 38/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.9215 - accuracy: 0.6419 - val_loss: 0.9694 - val_accuracy: 0.6134
# Epoch 39/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.9304 - accuracy: 0.6419 - val_loss: 0.7757 - val_accuracy: 0.6218
# Epoch 40/150
# 95/95 [==============================] - 1s 7ms/step - loss: 0.8446 - accuracy: 0.6589 - val_loss: 1.0852 - val_accuracy: 0.5966
# Epoch 41/150
# 95/95 [==============================] - 1s 8ms/step - loss: 1.0004 - accuracy: 0.6504 - val_loss: 0.7761 - val_accuracy: 0.6050
# Epoch 42/150
# 95/95 [==============================] - 0s 5ms/step - loss: 0.8124 - accuracy: 0.6568 - val_loss: 0.7921 - val_accuracy: 0.5798
# Epoch 43/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.8527 - accuracy: 0.6419 - val_loss: 1.0585 - val_accuracy: 0.6218
# Epoch 44/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.9089 - accuracy: 0.6441 - val_loss: 0.8390 - val_accuracy: 0.6134
# Epoch 45/150
# 95/95 [==============================] - 1s 6ms/step - loss: 0.9610 - accuracy: 0.6398 - val_loss: 0.9215 - val_accuracy: 0.5798
# Epoch 46/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.8262 - accuracy: 0.6462 - val_loss: 0.8456 - val_accuracy: 0.6218
# Epoch 47/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.8532 - accuracy: 0.6568 - val_loss: 1.0266 - val_accuracy: 0.5882
# Epoch 48/150
# 95/95 [==============================] - 0s 5ms/step - loss: 0.8479 - accuracy: 0.6504 - val_loss: 0.7757 - val_accuracy: 0.5798
# Epoch 49/150
# 95/95 [==============================] - 1s 6ms/step - loss: 1.1634 - accuracy: 0.6525 - val_loss: 1.2402 - val_accuracy: 0.5714
# Epoch 50/150
# 95/95 [==============================] - 1s 8ms/step - loss: 0.9138 - accuracy: 0.6737 - val_loss: 0.8776 - val_accuracy: 0.6050
# Epoch 51/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.8451 - accuracy: 0.6462 - val_loss: 0.7963 - val_accuracy: 0.6218
# Epoch 52/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8576 - accuracy: 0.6525 - val_loss: 0.7795 - val_accuracy: 0.5966
# Epoch 53/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.7959 - accuracy: 0.6462 - val_loss: 0.7686 - val_accuracy: 0.5882
# Epoch 54/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9150 - accuracy: 0.6780 - val_loss: 0.9311 - val_accuracy: 0.5966
# Epoch 55/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9095 - accuracy: 0.6462 - val_loss: 0.7985 - val_accuracy: 0.6050
# Epoch 56/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8249 - accuracy: 0.6674 - val_loss: 0.7792 - val_accuracy: 0.5714
# Epoch 57/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8991 - accuracy: 0.6631 - val_loss: 0.8915 - val_accuracy: 0.6050
# Epoch 58/150
# 95/95 [==============================] - 0s 4ms/step - loss: 0.8320 - accuracy: 0.6589 - val_loss: 0.9215 - val_accuracy: 0.5798
# Epoch 59/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8473 - accuracy: 0.6653 - val_loss: 0.7839 - val_accuracy: 0.6050
# Epoch 60/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9992 - accuracy: 0.6610 - val_loss: 0.9299 - val_accuracy: 0.5630
# Epoch 61/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.9065 - accuracy: 0.6610 - val_loss: 0.9546 - val_accuracy: 0.6050
# Epoch 62/150
# 95/95 [==============================] - 0s 2ms/step - loss: 1.0046 - accuracy: 0.6547 - val_loss: 0.7986 - val_accuracy: 0.6134
# Epoch 63/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8367 - accuracy: 0.6631 - val_loss: 0.7704 - val_accuracy: 0.6134
# Epoch 64/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8403 - accuracy: 0.6441 - val_loss: 0.8011 - val_accuracy: 0.5798
# Epoch 65/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7966 - accuracy: 0.6695 - val_loss: 0.7959 - val_accuracy: 0.6050
# Epoch 66/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8522 - accuracy: 0.6695 - val_loss: 0.7758 - val_accuracy: 0.5882
# Epoch 67/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8230 - accuracy: 0.6589 - val_loss: 0.9537 - val_accuracy: 0.6134
# Epoch 68/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8143 - accuracy: 0.6610 - val_loss: 0.8008 - val_accuracy: 0.6218
# Epoch 69/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7792 - accuracy: 0.6568 - val_loss: 0.8606 - val_accuracy: 0.5882
# Epoch 70/150
# 95/95 [==============================] - 0s 5ms/step - loss: 0.8141 - accuracy: 0.6504 - val_loss: 0.9597 - val_accuracy: 0.6218
# Epoch 71/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8674 - accuracy: 0.6441 - val_loss: 0.8368 - val_accuracy: 0.5798
# Epoch 72/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9444 - accuracy: 0.6547 - val_loss: 0.8363 - val_accuracy: 0.5882
# Epoch 73/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8175 - accuracy: 0.6462 - val_loss: 0.8012 - val_accuracy: 0.6218
# Epoch 74/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8083 - accuracy: 0.6547 - val_loss: 0.7970 - val_accuracy: 0.6218
# Epoch 75/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.9322 - accuracy: 0.6547 - val_loss: 0.8057 - val_accuracy: 0.5714
# Epoch 76/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7700 - accuracy: 0.6631 - val_loss: 0.7721 - val_accuracy: 0.5966
# Epoch 77/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8950 - accuracy: 0.6419 - val_loss: 0.7701 - val_accuracy: 0.5966
# Epoch 78/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7865 - accuracy: 0.6525 - val_loss: 0.8284 - val_accuracy: 0.5966
# Epoch 79/150
# 95/95 [==============================] - 0s 2ms/step - loss: 1.0132 - accuracy: 0.6568 - val_loss: 0.8213 - val_accuracy: 0.6218
# Epoch 80/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8575 - accuracy: 0.6610 - val_loss: 1.1256 - val_accuracy: 0.5798
# Epoch 81/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7526 - accuracy: 0.6589 - val_loss: 0.7708 - val_accuracy: 0.6050
# Epoch 82/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8644 - accuracy: 0.6610 - val_loss: 0.8983 - val_accuracy: 0.6134
# Epoch 83/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7958 - accuracy: 0.6674 - val_loss: 0.7834 - val_accuracy: 0.5714
# Epoch 84/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8072 - accuracy: 0.6568 - val_loss: 0.8144 - val_accuracy: 0.6050
# Epoch 85/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8009 - accuracy: 0.6653 - val_loss: 0.7833 - val_accuracy: 0.5798
# Epoch 86/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.9029 - accuracy: 0.6653 - val_loss: 0.8018 - val_accuracy: 0.5966
# Epoch 87/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8182 - accuracy: 0.6716 - val_loss: 0.9099 - val_accuracy: 0.5714
# Epoch 88/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9852 - accuracy: 0.6674 - val_loss: 0.8022 - val_accuracy: 0.5798
# Epoch 89/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7676 - accuracy: 0.6631 - val_loss: 0.7920 - val_accuracy: 0.5966
# Epoch 90/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8696 - accuracy: 0.6716 - val_loss: 0.8187 - val_accuracy: 0.5714
# Epoch 91/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8201 - accuracy: 0.6843 - val_loss: 0.7841 - val_accuracy: 0.5714
# Epoch 92/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8184 - accuracy: 0.6695 - val_loss: 0.8045 - val_accuracy: 0.5966
# Epoch 93/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8247 - accuracy: 0.6716 - val_loss: 0.8102 - val_accuracy: 0.5966
# Epoch 94/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7951 - accuracy: 0.6547 - val_loss: 0.7853 - val_accuracy: 0.5966
# Epoch 95/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7982 - accuracy: 0.6653 - val_loss: 0.8539 - val_accuracy: 0.6050
# Epoch 96/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8515 - accuracy: 0.6674 - val_loss: 0.8669 - val_accuracy: 0.6050
# Epoch 97/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8715 - accuracy: 0.6716 - val_loss: 0.8291 - val_accuracy: 0.6050
# Epoch 98/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.9606 - accuracy: 0.6716 - val_loss: 0.7687 - val_accuracy: 0.6050
# Epoch 99/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7627 - accuracy: 0.6801 - val_loss: 0.7769 - val_accuracy: 0.6050
# Epoch 100/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7765 - accuracy: 0.6737 - val_loss: 0.8909 - val_accuracy: 0.6050
# Epoch 101/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8538 - accuracy: 0.6801 - val_loss: 0.8003 - val_accuracy: 0.5798
# Epoch 102/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8550 - accuracy: 0.6716 - val_loss: 0.7622 - val_accuracy: 0.6050
# Epoch 103/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7908 - accuracy: 0.6907 - val_loss: 0.8171 - val_accuracy: 0.5798
# Epoch 104/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8585 - accuracy: 0.6737 - val_loss: 0.7813 - val_accuracy: 0.5882
# Epoch 105/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8128 - accuracy: 0.6907 - val_loss: 0.9502 - val_accuracy: 0.6050
# Epoch 106/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8302 - accuracy: 0.6695 - val_loss: 0.7623 - val_accuracy: 0.6050
# Epoch 107/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7791 - accuracy: 0.6631 - val_loss: 0.7616 - val_accuracy: 0.6134
# Epoch 108/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8115 - accuracy: 0.6716 - val_loss: 0.8626 - val_accuracy: 0.5882
# Epoch 109/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7867 - accuracy: 0.6843 - val_loss: 0.7759 - val_accuracy: 0.6218
# Epoch 110/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7764 - accuracy: 0.6843 - val_loss: 0.7828 - val_accuracy: 0.5882
# Epoch 111/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7895 - accuracy: 0.6695 - val_loss: 0.8330 - val_accuracy: 0.5882
# Epoch 112/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8918 - accuracy: 0.6589 - val_loss: 0.7637 - val_accuracy: 0.6218
# Epoch 113/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7530 - accuracy: 0.6674 - val_loss: 0.8421 - val_accuracy: 0.6218
# Epoch 114/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7917 - accuracy: 0.6864 - val_loss: 0.8877 - val_accuracy: 0.6218
# Epoch 115/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8181 - accuracy: 0.6843 - val_loss: 1.0095 - val_accuracy: 0.6218
# Epoch 116/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8304 - accuracy: 0.6758 - val_loss: 0.8203 - val_accuracy: 0.6134
# Epoch 117/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7432 - accuracy: 0.6843 - val_loss: 0.9743 - val_accuracy: 0.5882
# Epoch 118/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8642 - accuracy: 0.6716 - val_loss: 0.7690 - val_accuracy: 0.6134
# Epoch 119/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8303 - accuracy: 0.6822 - val_loss: 0.7669 - val_accuracy: 0.5798
# Epoch 120/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7522 - accuracy: 0.6864 - val_loss: 0.8556 - val_accuracy: 0.6050
# Epoch 121/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7785 - accuracy: 0.6695 - val_loss: 1.0375 - val_accuracy: 0.5798
# Epoch 122/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7639 - accuracy: 0.6886 - val_loss: 0.8876 - val_accuracy: 0.5798
# Epoch 123/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8672 - accuracy: 0.6758 - val_loss: 0.7611 - val_accuracy: 0.6050
# Epoch 124/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.9373 - accuracy: 0.6716 - val_loss: 0.7625 - val_accuracy: 0.6050
# Epoch 125/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7705 - accuracy: 0.6907 - val_loss: 0.7620 - val_accuracy: 0.6050
# Epoch 126/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7726 - accuracy: 0.6801 - val_loss: 0.7699 - val_accuracy: 0.5798
# Epoch 127/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7655 - accuracy: 0.6822 - val_loss: 0.7733 - val_accuracy: 0.5798
# Epoch 128/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8370 - accuracy: 0.6695 - val_loss: 0.7946 - val_accuracy: 0.5798
# Epoch 129/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7920 - accuracy: 0.6695 - val_loss: 0.9640 - val_accuracy: 0.5798
# Epoch 130/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.8150 - accuracy: 0.6801 - val_loss: 0.7641 - val_accuracy: 0.6050
# Epoch 131/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7526 - accuracy: 0.6907 - val_loss: 0.8396 - val_accuracy: 0.6050
# Epoch 132/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8285 - accuracy: 0.6864 - val_loss: 0.7676 - val_accuracy: 0.6050
# Epoch 133/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7681 - accuracy: 0.6928 - val_loss: 0.8481 - val_accuracy: 0.5798
# Epoch 134/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7930 - accuracy: 0.6780 - val_loss: 0.7661 - val_accuracy: 0.6050
# Epoch 135/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8333 - accuracy: 0.6843 - val_loss: 0.9093 - val_accuracy: 0.6050
# Epoch 136/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7792 - accuracy: 0.6758 - val_loss: 0.8009 - val_accuracy: 0.6050
# Epoch 137/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.9038 - accuracy: 0.6716 - val_loss: 0.7617 - val_accuracy: 0.6050
# Epoch 138/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7505 - accuracy: 0.6737 - val_loss: 0.7665 - val_accuracy: 0.6050
# Epoch 139/150
# 95/95 [==============================] - 0s 3ms/step - loss: 0.7578 - accuracy: 0.6737 - val_loss: 0.7685 - val_accuracy: 0.5798
# Epoch 140/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8893 - accuracy: 0.6886 - val_loss: 0.8807 - val_accuracy: 0.5798
# Epoch 141/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8814 - accuracy: 0.6843 - val_loss: 0.7735 - val_accuracy: 0.5882
# Epoch 142/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7974 - accuracy: 0.6737 - val_loss: 0.7606 - val_accuracy: 0.6050
# Epoch 143/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7402 - accuracy: 0.6949 - val_loss: 0.8773 - val_accuracy: 0.5798
# Epoch 144/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8107 - accuracy: 0.6737 - val_loss: 0.7745 - val_accuracy: 0.6050
# Epoch 145/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7938 - accuracy: 0.6674 - val_loss: 0.7972 - val_accuracy: 0.6134
# Epoch 146/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7533 - accuracy: 0.6822 - val_loss: 0.9636 - val_accuracy: 0.5798
# Epoch 147/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8139 - accuracy: 0.6695 - val_loss: 0.7579 - val_accuracy: 0.6050
# Epoch 148/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7346 - accuracy: 0.6801 - val_loss: 0.7597 - val_accuracy: 0.6050
# Epoch 149/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.7669 - accuracy: 0.6843 - val_loss: 0.8071 - val_accuracy: 0.6050
# Epoch 150/150
# 95/95 [==============================] - 0s 2ms/step - loss: 0.8261 - accuracy: 0.6801 - val_loss: 0.8085 - val_accuracy: 0.5798

# %%
# Create a list to store the selected features and their corresponding accuracies
base_features = common_data.columns.tolist()[:-1]
base_features
# Out:
# ['NARROWFACESECONDARYCOOLINGWATERPRESSUREACTUALMEAN',
#  'MOLDBROADFACE1INLETOUTLETWATERTEMP.DELTAMEAN',
#  'STEELLEVELINMOLD-SETMEAN',
#  'SEG0BSECONDARYCOOLINGWATERPRESSUREACTUALMEAN',
#  'SEG9+10+11+12BOTTOMSECONDARYCOOLINGWATERFLOWACTUALMEAN',
#  'LIQUIDUSTEMPMEAN',
#  'NARROWFACE1WATERFLOWMEAN',
#  'TUNDISHWEIGHTMEAN']

# %%
# Evaluate the model

testPredict_probs=base_model.predict(test_X)
#testPredict_probs

# Apply threshold to obtain predicted classes
threshold = 0.5  # Adjust this threshold as needed
y_pred = (testPredict_probs > threshold).astype(int)
y_pred

base_accuracy = accuracy_score(test_Y,y_pred)
base_accuracy

# %% [markdown]
# ### Data for new model

# %%
# %store -r feature_imp_RF
total_features=feature_imp_RF["Feature"]
total_features_list= total_features.tolist()

remaining_features=[]
for feature in total_features_list:
    if feature not in base_features:
        remaining_features.append(feature) 
        
len(remaining_features)

# %% [markdown]
# ### Iterating over remaining features

# %%
new_features=[]
count=0
optimal_features=[]
accuracy_store=[base_accuracy]

# Start the timer
start_time = time.time()

for feature in remaining_features:
    # Add one feature to the feature set
    new_features = base_features + [feature]
    
    #Creating a new data
    new_data=random_forest_data.loc[:,new_features]
    new_data = shuffle(new_data, random_state=42)
    
    #Splitting the new_data into train and test
    new_total_length= new_data.shape[0]
    new_train_size=int(new_data.shape[0]*0.8)
    new_test_size=new_data.shape[0]-train_size
    new_train_X=new_data.iloc[:,:][0:train_size].to_numpy().astype(nm.float32) #2D array
    new_train_Y=common_data['OUTPUT'][0:train_size].to_numpy().astype(nm.float32) #1D array
    new_train_Y=nm.reshape(train_Y,(train_Y.shape[0],1)) # 2D array
    new_test_X=new_data.iloc[:,:][train_size:].to_numpy().astype(nm.float32) #2D array
    new_test_Y=common_data['OUTPUT'][train_size:].to_numpy().astype(nm.float32) #1D array
    new_test_Y=nm.reshape(test_Y,(test_Y.shape[0],1)) # 2D array}

    
    # Create a new model with the updated feature set
    new_model=Sequential() 
    new_model.add(Dense(50,input_dim=len(new_features),activation='relu',kernel_regularizer=l2(0.01))) # one hidden layer
    new_model.add(Dense(1,activation='sigmoid',kernel_regularizer=l2(0.01))) #output layer
        
    # Compile the new model
    new_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    
    print(count)
    print(feature)
    
    
    # Train the new model
    new_model.fit(new_train_X,new_train_Y,epochs=150,batch_size=5,validation_data=(new_test_X,new_test_Y))
    
    # Evaluate the new model
    testPredict_probs_new=new_model.predict(new_test_X)
    threshold = 0.5  # Adjust this threshold as needed
    y_new_pred = (testPredict_probs_new > threshold).astype(int)
    new_accuracy = accuracy_score(new_test_Y,y_new_pred)
    accuracy_store.append(new_accuracy)
    
    # Update the baseline feature set if the accuracy score improved
    if new_accuracy> base_accuracy:
        base_features = new_features
        base_accuracy = new_accuracy
        optimal_features.append(new_features)
    
    # Check for convergence
    #if len(base_features) == random_forest_data.iloc[:,:-1].shape[1]:
     #   break
        
# Stop the timer and calculate the elapsed time
end_time = time.time()
training_time = end_time - start_time

# %%
print("Simulation ended",training_time)
print("Best feature set:", base_features)
print("Best accuracy score:", base_accuracy)

# %%
accuracy_store

# %%
# %store accuracy_store
# %store base_features
# %store base_accuracy
# %store optimal_features

# %%
len(base_features)
base_features

# %%
common_data.columns

# %%
new_features=[]
for feature in remaining_features:
    # Add one feature to the feature set
    new_features = base_features + [feature]

# %%
new_features

# %%
#Creating a new data
new_data=random_forest_data.loc[:,new_features]
new_data = shuffle(new_data, random_state=42)
new_data.shape

# %%
 #Splitting the new_data into train and test
new_total_length= new_data.shape[0]
new_train_size=int(new_data.shape[0]*0.8)
new_test_size=new_data.shape[0]-train_size
new_train_X=new_data.iloc[:,:][0:train_size].to_numpy().astype(nm.float32) #2D array
new_train_Y=common_data['OUTPUT'][0:train_size].to_numpy().astype(nm.float32) #1D array
new_train_Y=nm.reshape(train_Y,(train_Y.shape[0],1)) # 2D array
new_test_X=new_data.iloc[:,:][train_size:].to_numpy().astype(nm.float32) #2D array
new_test_Y=common_data['OUTPUT'][train_size:].to_numpy().astype(nm.float32) #1D array
new_test_Y=nm.reshape(test_Y,(test_Y.shape[0],1)) # 2D array

# %%
new_train_X.shape

# %%
# Create a new model with the updated feature set
new_model=Sequential() 
new_model.add(Dense(50,input_dim=len(new_features),activation='relu',kernel_regularizer=l2(0.01))) # one hidden layer
new_model.add(Dense(1,activation='sigmoid',kernel_regularizer=l2(0.01))) #output layer

# %%
# Compile the new model
new_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    
# Train the new model
new_model.fit(new_train_X,new_train_Y,epochs=150,batch_size=5,validation_data=(new_test_X,new_test_Y))

# Evaluate the new model
testPredict_probs_new=new_model.predict(new_test_X)
threshold = 0.5  # Adjust this threshold as needed
y_new_pred = (testPredict_probs_new > threshold).astype(int)
new_accuracy = accuracy_score(new_test_Y,y_new_pred)

# %%
random_forest_data.iloc[:,:-1].shape[1]

# %%
import time

# Compile the new model
new_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Start the timer
start_time = time.time()

# Train the new model
new_model.fit(new_train_X, new_train_Y, epochs=150, batch_size=5, validation_data=(new_test_X, new_test_Y))

# Stop the timer and calculate the elapsed time
end_time = time.time()
training_time = end_time - start_time

# Evaluate the new model
testPredict_probs_new = new_model.predict(new_test_X)
threshold = 0.5  # Adjust this threshold as needed
y_new_pred = (testPredict_probs_new > threshold).astype(int)
new_accuracy = accuracy_score(new_test_Y, y_new_pred)

# Print the training time
print("Training Time: {:.2f} seconds".format(training_time))

# %%
a=[1]
a.append(2)

# %%
a

# %%
a=0.69
b=0.5

# %%
print(a>b)

# %%
print(b>a)
