# %% [markdown]
# #### This code file is same as of 1 ANN training using iterative feature selection process with base model being on common features.
#
# #### Changes made are in this file considers all five output columns for generating a final output binary value. Other hyperparameters too ar changed

# %%
#Import all the necessary libraries
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 4 steps neeeded to be done for the code to be reproducible.

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as nm
nm.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
# for later versions:
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# Check GPU availability
print("GPU Available:", tf.config.list_physical_devices("GPU"))

# Check CPU availability
print("CPU Available:", tf.config.list_physical_devices("CPU"))

import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler 
from keras.models import Sequential #importing Sequential Model.It uses tensorflow backend and you need to have tensorflow setup. 
from keras.layers import Dense #Importing default dense layer
from sklearn.utils import shuffle
from keras.regularizers import l1, l2
from keras.optimizers import SGD
from sklearn.metrics import accuracy_score
import time


path_dir='C:/Users/subhi/AMNS_Second_phase_ANN_model/Datasets/'
filename1='Common_Data.xlsx'
filename2='Intersection_Data.xlsx'

#Access all the necessary variables and datasets
# %store -r common_data 
# %store -r random_forest_data
random_forest_data.shape #161 statistical features and one output column
# Using the common_data dataframe created in ANN_Model_on_common_features
#Using the appended_data dataframe created in Random_Forest_Code 
common_data
# Out:
# WARNING:tensorflow:From C:\Users\subhi\AppData\Local\Temp\ipykernel_17528\4235223637.py:30: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# GPU Available: []
# CPU Available: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
#      NARROWFACESECONDARYCOOLINGWATERPRESSUREACTUALMEAN  \
# 0                                             4.925862
# 1                                             4.915455
# 2                                             5.482414
# 3                                             5.471203
# 4                                             5.081299
# ..                                                 ...
# 586                                           2.140476
# 587                                           2.098624
# 588                                           2.097216
# 589                                           2.091311
# 590                                           2.086576
#
#      MOLDBROADFACE1INLETOUTLETWATERTEMP.DELTAMEAN  STEELLEVELINMOLD-SETMEAN  \
# 0                                        4.000000                 80.103621
# 1                                        4.000000                 80.104899
# 2                                        4.000000                 80.106667
# 3                                        4.000000                 80.108861
# 4                                        4.000000                 80.110282
# ..                                            ...                       ...
# 586                                      7.994048                 80.108333
# 587                                      8.052910                 80.107513
# 588                                      7.407216                 80.109175
# 589                                      7.121359                 80.106019
# 590                                      7.065217                 80.105435
#
#      SEG0BSECONDARYCOOLINGWATERPRESSUREACTUALMEAN  \
# 0                                        1.177759
# 1                                        1.170657
# 2                                        1.239828
# 3                                        1.240000
# 4                                        1.190000
# ..                                            ...
# 586                                      0.789524
# 587                                      0.334974
# 588                                      0.544330
# 589                                      0.722087
# 590                                      0.859620
#
#      SEG9+10+11+12BOTTOMSECONDARYCOOLINGWATERFLOWACTUALMEAN  LIQUIDUSTEMPMEAN  \
# 0                                           190.958678             1521.40790
# 1                                           195.140556             1521.76000
# 2                                           191.464138             1521.26000
# 3                                           187.756139             1521.74000
# 4                                           188.373955             1521.41000
# ..                                                 ...                    ...
# 586                                         213.972321             1514.56430
# 587                                         204.833228             1515.94260
# 588                                         213.607887             1512.56210
# 589                                          31.653689             1512.88320
# 590                                          31.550598             1512.30945
#
#      NARROWFACE1WATERFLOWMEAN  TUNDISHWEIGHTMEAN  OUTPUT
# 0                  461.735632          23.854885       1
# 1                  461.954545          23.548081       1
# 2                  461.534483          24.320115       0
# 3                  461.892405          24.275696       0
# 4                  462.028249          24.563785       1
# ..                        ...                ...     ...
# 586                452.720238          23.541369       0
# 587                443.820106          27.779471       1
# 588                452.283505          22.814948       1
# 589                452.150485          24.742087       1
# 590                452.614130          24.789022       1
#
# [591 rows x 9 columns]

# %% [markdown]
# #### Training the base model which is done in six steps 1) Splitting the data 2)Scaling the data 3)Defining the model 4)Compiling the model 5)Fit the data  6) Evaluate the model.

# %%
def training_data(data):
    data=shuffle(data,random_state=42)
    
    #Defining train and test sizes
    total_length= data.shape[0]
    train_size=int(data.shape[0]*0.8)
    test_size=data.shape[0]-train_size
    
    # First converting dataframe series into numpy array and setting the datatype as float32 for all data
    # In second step converting all 1D array into 2D array
    train_X=data.iloc[:,:-1][0:train_size].to_numpy().astype(nm.float32) #2D array

    train_Y=common_data['OUTPUT'][0:train_size].to_numpy().astype(nm.float32) #1D array
    train_Y=nm.reshape(train_Y,(train_Y.shape[0],1)) # 2D array

    test_X=common_data.iloc[:,:-1][train_size:].to_numpy().astype(nm.float32) #2D array

    test_Y=common_data['OUTPUT'][train_size:].to_numpy().astype(nm.float32) #1D array
    test_Y=nm.reshape(test_Y,(test_Y.shape[0],1)) # 2D array
    
    scaler=RobustScaler()
    train_X=scaler.fit_transform(train_X) 
    test_X=scaler.transform(test_X)
    
    model=Sequential() 
    model.add(Dense(50,input_dim=len(train_X[0,:]),activation='relu',kernel_regularizer=l2(0.01))) # one hidden layer
    model.add(Dense(1,activation='sigmoid',kernel_regularizer=l2(0.01))) #output layer
        
base_model.summary()

# %%
common_data = shuffle(common_data, random_state=42)
#Defining train and test sizes
total_length= common_data.shape[0]
train_size=int(common_data.shape[0]*0.8)
test_size=common_data.shape[0]-train_size

# First converting dataframe series into numpy array and setting the datatype as float32 for all data
# In second step converting all 1D array into 2D array
train_X=common_data.iloc[:,:-1][0:train_size].to_numpy().astype(nm.float32) #2D array

train_Y=common_data['OUTPUT'][0:train_size].to_numpy().astype(nm.float32) #1D array
train_Y=nm.reshape(train_Y,(train_Y.shape[0],1)) # 2D array

test_X=common_data.iloc[:,:-1][train_size:].to_numpy().astype(nm.float32) #2D array

test_Y=common_data['OUTPUT'][train_size:].to_numpy().astype(nm.float32) #1D array
test_Y=nm.reshape(test_Y,(test_Y.shape[0],1)) # 2D array

print('Dimension of training data',train_X.shape)
print('Dimension of testing data',test_X.shape)

#print(train_X)
print(type(train_X))
print(train_Y.shape)
test_Y.shape #2-D array
#train_Y

#scaler=StandardScaler()
#scaler=MinMaxScaler(feature_range=(0,1)) # scaler object
scaler=RobustScaler()
# First fit the scaler with your training data.
# It will find those parameters using which it is going to scale.
# Then transform any data you want.

train_X=scaler.fit_transform(train_X) 

# Since it has scaled  the data as per the parameters it learnt during training data.
# So it will require 2D array/similiar dimension as of training data.
# So testing data should be a 2D array.
# Testing data only need to be transformed on the basis of the parameters learnt using fit function on training data.

test_X=scaler.transform(test_X) #Scaling the training data and using the same parameters for testing data
#test
#train_X[:]


#Creating a Model
print('Total No of features',len(train_X[0,:])) #No of features
base_model=Sequential() 

base_model.add(Dense(50,input_dim=len(train_X[0,:]),activation='relu',kernel_regularizer=l2(0.01))) # one hidden layer
base_model.add(Dense(1,activation='sigmoid',kernel_regularizer=l2(0.01))) #output layer
        
base_model.summary()

#model.compile(optimizer='_' , loss='_' , metrics=['accuracy'])
base_model.compile(loss='binary_crossentropy',optimizer=SGD(momentum=0.9),metrics=['accuracy'])

#Fitting the training data
#base_model.fit(training data input, training data output, batch_size=_,validation_data=(x_test,y_test))
base_model.fit(train_X,train_Y,epochs=150,batch_size=len(train_X),validation_data=(test_X,test_Y))

# Epochs is number of times i want to do forward and backward propogation.
# batch size is used for update the weights in mini batches. The default back size is 32.
# Validation data : accuracy looking like on validation data after every epoch, you can give test data here too. 
#The loss will be reduced due to backpropgation through time.

#Add regularization or increase number of epochs for better accuracy.

# Evaluate the base model

testPredict_probs=base_model.predict(test_X)
#testPredict_probs

# Apply threshold to obtain predicted classes
threshold = 0.5  # Adjust this threshold as needed
y_pred = (testPredict_probs > threshold).astype(int)
y_pred

base_accuracy = accuracy_score(test_Y,y_pred)
base_accuracy
# Out:
# Dimension of training data (472, 8)
# Dimension of testing data (119, 8)
# <class 'numpy.ndarray'>
# (472, 1)
# Total No of features 8
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                450
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 1/1 [==============================] - 1s 502ms/step - loss: 20.4979 - accuracy: 0.5233 - val_loss: 6.6152 - val_accuracy: 0.5630
# Epoch 2/150
# 1/1 [==============================] - 0s 31ms/step - loss: 10.5079 - accuracy: 0.5678 - val_loss: 8.1061 - val_accuracy: 0.5798
# Epoch 3/150
# 1/1 [==============================] - 0s 32ms/step - loss: 13.0254 - accuracy: 0.5699 - val_loss: 4.2342 - val_accuracy: 0.5798
# Epoch 4/150
# 1/1 [==============================] - 0s 29ms/step - loss: 6.5092 - accuracy: 0.5869 - val_loss: 1.0057 - val_accuracy: 0.5210
# Epoch 5/150
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0625 - accuracy: 0.5551 - val_loss: 0.9062 - val_accuracy: 0.5126
# Epoch 6/150
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8559 - accuracy: 0.5572 - val_loss: 0.9365 - val_accuracy: 0.5126
# Epoch 7/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8724 - accuracy: 0.5487 - val_loss: 0.9754 - val_accuracy: 0.5042
# Epoch 8/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8966 - accuracy: 0.5466 - val_loss: 1.0222 - val_accuracy: 0.5042
# Epoch 9/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9288 - accuracy: 0.5424 - val_loss: 1.0745 - val_accuracy: 0.5042
# Epoch 10/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9675 - accuracy: 0.5445 - val_loss: 1.1292 - val_accuracy: 0.5294
# Epoch 11/150
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0090 - accuracy: 0.5466 - val_loss: 1.1830 - val_accuracy: 0.5210
# Epoch 12/150
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0500 - accuracy: 0.5530 - val_loss: 1.2328 - val_accuracy: 0.5378
# Epoch 13/150
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0884 - accuracy: 0.5593 - val_loss: 1.2767 - val_accuracy: 0.5294
# Epoch 14/150
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1226 - accuracy: 0.5636 - val_loss: 1.3136 - val_accuracy: 0.5210
# Epoch 15/150
# 1/1 [==============================] - 0s 27ms/step - loss: 1.1516 - accuracy: 0.5657 - val_loss: 1.3428 - val_accuracy: 0.5210
# Epoch 16/150
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1749 - accuracy: 0.5805 - val_loss: 1.3642 - val_accuracy: 0.5042
# Epoch 17/150
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1922 - accuracy: 0.5763 - val_loss: 1.3778 - val_accuracy: 0.5042
# Epoch 18/150
# 1/1 [==============================] - 0s 28ms/step - loss: 1.2039 - accuracy: 0.5869 - val_loss: 1.3899 - val_accuracy: 0.4874
# Epoch 19/150
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2160 - accuracy: 0.5699 - val_loss: 1.3847 - val_accuracy: 0.5294
# Epoch 20/150
# 1/1 [==============================] - 0s 26ms/step - loss: 1.2134 - accuracy: 0.6186 - val_loss: 1.3799 - val_accuracy: 0.5378
# Epoch 21/150
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2129 - accuracy: 0.6123 - val_loss: 1.3706 - val_accuracy: 0.5714
# Epoch 22/150
# 1/1 [==============================] - 0s 41ms/step - loss: 1.2098 - accuracy: 0.6102 - val_loss: 1.3579 - val_accuracy: 0.5798
# Epoch 23/150
# 1/1 [==============================] - 0s 29ms/step - loss: 1.2043 - accuracy: 0.6165 - val_loss: 1.3423 - val_accuracy: 0.5714
# Epoch 24/150
# 1/1 [==============================] - 0s 30ms/step - loss: 1.1971 - accuracy: 0.6271 - val_loss: 1.3250 - val_accuracy: 0.5630
# Epoch 25/150
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1887 - accuracy: 0.6292 - val_loss: 1.3067 - val_accuracy: 0.5462
# Epoch 26/150
# 1/1 [==============================] - 0s 27ms/step - loss: 1.1797 - accuracy: 0.6186 - val_loss: 1.2881 - val_accuracy: 0.5630
# Epoch 27/150
# 1/1 [==============================] - 0s 27ms/step - loss: 1.1702 - accuracy: 0.6165 - val_loss: 1.2699 - val_accuracy: 0.5462
# Epoch 28/150
# 1/1 [==============================] - 0s 35ms/step - loss: 1.1608 - accuracy: 0.6165 - val_loss: 1.2523 - val_accuracy: 0.5546
# Epoch 29/150
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1516 - accuracy: 0.6165 - val_loss: 1.2357 - val_accuracy: 0.5546
# Epoch 30/150
# 1/1 [==============================] - 0s 27ms/step - loss: 1.1427 - accuracy: 0.6165 - val_loss: 1.2201 - val_accuracy: 0.5462
# Epoch 31/150
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1343 - accuracy: 0.6165 - val_loss: 1.2059 - val_accuracy: 0.5294
# Epoch 32/150
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1265 - accuracy: 0.6208 - val_loss: 1.1931 - val_accuracy: 0.5210
# Epoch 33/150
# 1/1 [==============================] - 0s 32ms/step - loss: 1.1193 - accuracy: 0.6144 - val_loss: 1.1818 - val_accuracy: 0.5210
# Epoch 34/150
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1128 - accuracy: 0.6102 - val_loss: 1.1720 - val_accuracy: 0.5042
# Epoch 35/150
# 1/1 [==============================] - 0s 30ms/step - loss: 1.1069 - accuracy: 0.6059 - val_loss: 1.1634 - val_accuracy: 0.5042
# Epoch 36/150
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1016 - accuracy: 0.5932 - val_loss: 1.1561 - val_accuracy: 0.5126
# Epoch 37/150
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0969 - accuracy: 0.5975 - val_loss: 1.1498 - val_accuracy: 0.5126
# Epoch 38/150
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0926 - accuracy: 0.5953 - val_loss: 1.1443 - val_accuracy: 0.5210
# Epoch 39/150
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0886 - accuracy: 0.5805 - val_loss: 1.1393 - val_accuracy: 0.5294
# Epoch 40/150
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0847 - accuracy: 0.5826 - val_loss: 1.1345 - val_accuracy: 0.5294
# Epoch 41/150
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0808 - accuracy: 0.5805 - val_loss: 1.1298 - val_accuracy: 0.5378
# Epoch 42/150
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0766 - accuracy: 0.5826 - val_loss: 1.1248 - val_accuracy: 0.5462
# Epoch 43/150
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0721 - accuracy: 0.5869 - val_loss: 1.1195 - val_accuracy: 0.5462
# Epoch 44/150
# 1/1 [==============================] - 0s 35ms/step - loss: 1.0670 - accuracy: 0.5869 - val_loss: 1.1140 - val_accuracy: 0.5462
# Epoch 45/150
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0614 - accuracy: 0.5911 - val_loss: 1.1082 - val_accuracy: 0.5462
# Epoch 46/150
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0554 - accuracy: 0.5911 - val_loss: 1.1022 - val_accuracy: 0.5462
# Epoch 47/150
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0490 - accuracy: 0.5953 - val_loss: 1.0962 - val_accuracy: 0.5546
# Epoch 48/150
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0422 - accuracy: 0.5996 - val_loss: 1.0902 - val_accuracy: 0.5630
# Epoch 49/150
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0354 - accuracy: 0.5975 - val_loss: 1.0844 - val_accuracy: 0.5714
# Epoch 50/150
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0285 - accuracy: 0.6017 - val_loss: 1.0789 - val_accuracy: 0.5714
# Epoch 51/150
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0218 - accuracy: 0.6017 - val_loss: 1.0736 - val_accuracy: 0.5630
# Epoch 52/150
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0153 - accuracy: 0.5932 - val_loss: 1.0686 - val_accuracy: 0.5798
# Epoch 53/150
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0091 - accuracy: 0.5932 - val_loss: 1.0640 - val_accuracy: 0.5882
# Epoch 54/150
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0032 - accuracy: 0.5996 - val_loss: 1.0597 - val_accuracy: 0.5714
# Epoch 55/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9978 - accuracy: 0.6081 - val_loss: 1.0557 - val_accuracy: 0.5714
# Epoch 56/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9927 - accuracy: 0.6186 - val_loss: 1.0520 - val_accuracy: 0.5798
# Epoch 57/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9880 - accuracy: 0.6292 - val_loss: 1.0484 - val_accuracy: 0.5714
# Epoch 58/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9836 - accuracy: 0.6229 - val_loss: 1.0450 - val_accuracy: 0.5630
# Epoch 59/150
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9794 - accuracy: 0.6335 - val_loss: 1.0416 - val_accuracy: 0.5546
# Epoch 60/150
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9755 - accuracy: 0.6314 - val_loss: 1.0384 - val_accuracy: 0.5546
# Epoch 61/150
# 1/1 [==============================] - 0s 36ms/step - loss: 0.9719 - accuracy: 0.6398 - val_loss: 1.0351 - val_accuracy: 0.5546
# Epoch 62/150
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9683 - accuracy: 0.6356 - val_loss: 1.0318 - val_accuracy: 0.5630
# Epoch 63/150
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9649 - accuracy: 0.6377 - val_loss: 1.0285 - val_accuracy: 0.5630
# Epoch 64/150
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9616 - accuracy: 0.6462 - val_loss: 1.0250 - val_accuracy: 0.5630
# Epoch 65/150
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9584 - accuracy: 0.6441 - val_loss: 1.0215 - val_accuracy: 0.5546
# Epoch 66/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9552 - accuracy: 0.6483 - val_loss: 1.0180 - val_accuracy: 0.5546
# Epoch 67/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9520 - accuracy: 0.6504 - val_loss: 1.0144 - val_accuracy: 0.5630
# Epoch 68/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9490 - accuracy: 0.6483 - val_loss: 1.0108 - val_accuracy: 0.5630
# Epoch 69/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9460 - accuracy: 0.6504 - val_loss: 1.0072 - val_accuracy: 0.5714
# Epoch 70/150
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9430 - accuracy: 0.6525 - val_loss: 1.0037 - val_accuracy: 0.5714
# Epoch 71/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9402 - accuracy: 0.6483 - val_loss: 1.0002 - val_accuracy: 0.5714
# Epoch 72/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9375 - accuracy: 0.6547 - val_loss: 0.9969 - val_accuracy: 0.5630
# Epoch 73/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9348 - accuracy: 0.6589 - val_loss: 0.9936 - val_accuracy: 0.5882
# Epoch 74/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9323 - accuracy: 0.6568 - val_loss: 0.9905 - val_accuracy: 0.5966
# Epoch 75/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9299 - accuracy: 0.6589 - val_loss: 0.9875 - val_accuracy: 0.6050
# Epoch 76/150
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9275 - accuracy: 0.6653 - val_loss: 0.9846 - val_accuracy: 0.6218
# Epoch 77/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9253 - accuracy: 0.6674 - val_loss: 0.9818 - val_accuracy: 0.6303
# Epoch 78/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9231 - accuracy: 0.6631 - val_loss: 0.9792 - val_accuracy: 0.6303
# Epoch 79/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9211 - accuracy: 0.6674 - val_loss: 0.9767 - val_accuracy: 0.6218
# Epoch 80/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9191 - accuracy: 0.6610 - val_loss: 0.9743 - val_accuracy: 0.6218
# Epoch 81/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9171 - accuracy: 0.6631 - val_loss: 0.9721 - val_accuracy: 0.6218
# Epoch 82/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9152 - accuracy: 0.6610 - val_loss: 0.9699 - val_accuracy: 0.6134
# Epoch 83/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9133 - accuracy: 0.6631 - val_loss: 0.9678 - val_accuracy: 0.6134
# Epoch 84/150
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9114 - accuracy: 0.6610 - val_loss: 0.9658 - val_accuracy: 0.6134
# Epoch 85/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9096 - accuracy: 0.6674 - val_loss: 0.9639 - val_accuracy: 0.6134
# Epoch 86/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9078 - accuracy: 0.6758 - val_loss: 0.9620 - val_accuracy: 0.6471
# Epoch 87/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9059 - accuracy: 0.6737 - val_loss: 0.9602 - val_accuracy: 0.6555
# Epoch 88/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9041 - accuracy: 0.6758 - val_loss: 0.9584 - val_accuracy: 0.6555
# Epoch 89/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9023 - accuracy: 0.6716 - val_loss: 0.9567 - val_accuracy: 0.6555
# Epoch 90/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9006 - accuracy: 0.6695 - val_loss: 0.9550 - val_accuracy: 0.6555
# Epoch 91/150
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8988 - accuracy: 0.6737 - val_loss: 0.9534 - val_accuracy: 0.6639
# Epoch 92/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8971 - accuracy: 0.6780 - val_loss: 0.9518 - val_accuracy: 0.6639
# Epoch 93/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8954 - accuracy: 0.6780 - val_loss: 0.9502 - val_accuracy: 0.6639
# Epoch 94/150
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8937 - accuracy: 0.6758 - val_loss: 0.9487 - val_accuracy: 0.6723
# Epoch 95/150
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8920 - accuracy: 0.6780 - val_loss: 0.9472 - val_accuracy: 0.6723
# Epoch 96/150
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8904 - accuracy: 0.6716 - val_loss: 0.9457 - val_accuracy: 0.6723
# Epoch 97/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8888 - accuracy: 0.6716 - val_loss: 0.9442 - val_accuracy: 0.6723
# Epoch 98/150
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8872 - accuracy: 0.6737 - val_loss: 0.9427 - val_accuracy: 0.6723
# Epoch 99/150
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8856 - accuracy: 0.6737 - val_loss: 0.9413 - val_accuracy: 0.6807
# Epoch 100/150
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8840 - accuracy: 0.6758 - val_loss: 0.9398 - val_accuracy: 0.6807
# Epoch 101/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8825 - accuracy: 0.6758 - val_loss: 0.9383 - val_accuracy: 0.6723
# Epoch 102/150
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8810 - accuracy: 0.6737 - val_loss: 0.9368 - val_accuracy: 0.6723
# Epoch 103/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8795 - accuracy: 0.6716 - val_loss: 0.9354 - val_accuracy: 0.6807
# Epoch 104/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8780 - accuracy: 0.6758 - val_loss: 0.9339 - val_accuracy: 0.6807
# Epoch 105/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8766 - accuracy: 0.6801 - val_loss: 0.9325 - val_accuracy: 0.6807
# Epoch 106/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8751 - accuracy: 0.6864 - val_loss: 0.9310 - val_accuracy: 0.6807
# Epoch 107/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8737 - accuracy: 0.6864 - val_loss: 0.9295 - val_accuracy: 0.6807
# Epoch 108/150
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8723 - accuracy: 0.6864 - val_loss: 0.9281 - val_accuracy: 0.6807
# Epoch 109/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8709 - accuracy: 0.6864 - val_loss: 0.9266 - val_accuracy: 0.6807
# Epoch 110/150
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8696 - accuracy: 0.6864 - val_loss: 0.9251 - val_accuracy: 0.6807
# Epoch 111/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8682 - accuracy: 0.6886 - val_loss: 0.9237 - val_accuracy: 0.6807
# Epoch 112/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8669 - accuracy: 0.6886 - val_loss: 0.9223 - val_accuracy: 0.6807
# Epoch 113/150
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8655 - accuracy: 0.6907 - val_loss: 0.9208 - val_accuracy: 0.6891
# Epoch 114/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8642 - accuracy: 0.6992 - val_loss: 0.9194 - val_accuracy: 0.6891
# Epoch 115/150
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8629 - accuracy: 0.7013 - val_loss: 0.9180 - val_accuracy: 0.6891
# Epoch 116/150
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8616 - accuracy: 0.7013 - val_loss: 0.9167 - val_accuracy: 0.6891
# Epoch 117/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8603 - accuracy: 0.7013 - val_loss: 0.9153 - val_accuracy: 0.6891
# Epoch 118/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8590 - accuracy: 0.7055 - val_loss: 0.9139 - val_accuracy: 0.6891
# Epoch 119/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8577 - accuracy: 0.7076 - val_loss: 0.9126 - val_accuracy: 0.6891
# Epoch 120/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8565 - accuracy: 0.7119 - val_loss: 0.9113 - val_accuracy: 0.6975
# Epoch 121/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8552 - accuracy: 0.7161 - val_loss: 0.9099 - val_accuracy: 0.6975
# Epoch 122/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8540 - accuracy: 0.7182 - val_loss: 0.9086 - val_accuracy: 0.7059
# Epoch 123/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8527 - accuracy: 0.7182 - val_loss: 0.9073 - val_accuracy: 0.7059
# Epoch 124/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8515 - accuracy: 0.7203 - val_loss: 0.9061 - val_accuracy: 0.7059
# Epoch 125/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8503 - accuracy: 0.7225 - val_loss: 0.9048 - val_accuracy: 0.7059
# Epoch 126/150
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8491 - accuracy: 0.7246 - val_loss: 0.9036 - val_accuracy: 0.7059
# Epoch 127/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8479 - accuracy: 0.7225 - val_loss: 0.9023 - val_accuracy: 0.7059
# Epoch 128/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8467 - accuracy: 0.7246 - val_loss: 0.9011 - val_accuracy: 0.7059
# Epoch 129/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8455 - accuracy: 0.7225 - val_loss: 0.8999 - val_accuracy: 0.7059
# Epoch 130/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8444 - accuracy: 0.7225 - val_loss: 0.8987 - val_accuracy: 0.7059
# Epoch 131/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8432 - accuracy: 0.7246 - val_loss: 0.8976 - val_accuracy: 0.6975
# Epoch 132/150
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8421 - accuracy: 0.7225 - val_loss: 0.8964 - val_accuracy: 0.6975
# Epoch 133/150
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8409 - accuracy: 0.7225 - val_loss: 0.8953 - val_accuracy: 0.6975
# Epoch 134/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8398 - accuracy: 0.7225 - val_loss: 0.8941 - val_accuracy: 0.7059
# Epoch 135/150
# 1/1 [==============================] - 0s 42ms/step - loss: 0.8387 - accuracy: 0.7225 - val_loss: 0.8930 - val_accuracy: 0.7059
# Epoch 136/150
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8376 - accuracy: 0.7225 - val_loss: 0.8919 - val_accuracy: 0.7059
# Epoch 137/150
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8364 - accuracy: 0.7246 - val_loss: 0.8908 - val_accuracy: 0.7059
# Epoch 138/150
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8353 - accuracy: 0.7246 - val_loss: 0.8897 - val_accuracy: 0.7059
# Epoch 139/150
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8342 - accuracy: 0.7246 - val_loss: 0.8886 - val_accuracy: 0.7059
# Epoch 140/150
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8332 - accuracy: 0.7246 - val_loss: 0.8875 - val_accuracy: 0.7059
# Epoch 141/150
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8321 - accuracy: 0.7246 - val_loss: 0.8864 - val_accuracy: 0.7059
# Epoch 142/150
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8310 - accuracy: 0.7246 - val_loss: 0.8854 - val_accuracy: 0.7059
# Epoch 143/150
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8299 - accuracy: 0.7246 - val_loss: 0.8843 - val_accuracy: 0.7059
# Epoch 144/150
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8288 - accuracy: 0.7267 - val_loss: 0.8832 - val_accuracy: 0.7059
# Epoch 145/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8278 - accuracy: 0.7288 - val_loss: 0.8822 - val_accuracy: 0.7059
# Epoch 146/150
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8267 - accuracy: 0.7288 - val_loss: 0.8811 - val_accuracy: 0.7143
# Epoch 147/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8257 - accuracy: 0.7288 - val_loss: 0.8801 - val_accuracy: 0.7143
# Epoch 148/150
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8246 - accuracy: 0.7288 - val_loss: 0.8791 - val_accuracy: 0.7143
# Epoch 149/150
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8236 - accuracy: 0.7288 - val_loss: 0.8780 - val_accuracy: 0.7143
# Epoch 150/150
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8226 - accuracy: 0.7288 - val_loss: 0.8770 - val_accuracy: 0.7143
# 4/4 [==============================] - 0s 998us/step
# 0.7142857142857143

# %%
# Create a list to store the selected features and their corresponding accuracies
base_features = common_data.columns.tolist()[:-1]
base_features

new_accuracy=training_data(base_features,common_data)

# %%
print(new_accuracy)
base_features

# %%
new_data=common_data.loc[:,base_features]
new_data

# %% [markdown]
# ### Data for new model

# %%
# %store -r feature_imp_RF 
#using it from Random_Forest_Code
#it is a dataframe which stores the features and their corresponding importance score in descending order
total_features=feature_imp_RF["Feature"]
total_features_list= total_features.tolist()

remaining_features=[]
for feature in total_features_list:
    if feature not in base_features:
        remaining_features.append(feature) 
        
print(len(remaining_features))
#feature_imp_RF["Feature"]

# %% [markdown]
# ### Iterating over remaining features and training at each iteration

# %%
new_features=[]
optimal_features=[]
accuracy_store=[base_accuracy]

# Start the timer
start_time = time.time()

for feature in remaining_features:
    # Add one feature to the feature set
    new_features = base_features + [feature]
    
    #Creating a new data and shuffling the data
    new_data=random_forest_data.loc[:,new_features]
    new_data = shuffle(new_data, random_state=42)
    
    #1 Splitting the new_data into train and test
    new_total_length= new_data.shape[0]
    new_train_size=int(new_data.shape[0]*0.8)
    new_test_size=new_data.shape[0]-new_train_size
    
    new_train_X=new_data.iloc[:,:][0:new_train_size].to_numpy().astype(nm.float32) #2D array
    new_train_Y=random_forest_data['OUTPUT'][0:new_train_size].to_numpy().astype(nm.float32) #1D array
    new_train_Y=nm.reshape(new_train_Y,(new_train_Y.shape[0],1)) # 2D array
    
    new_test_X=new_data.iloc[:,:][new_train_size:].to_numpy().astype(nm.float32) #2D array
    new_test_Y=random_forest_data['OUTPUT'][new_train_size:].to_numpy().astype(nm.float32) #1D array
    new_test_Y=nm.reshape(new_test_Y,(new_test_Y.shape[0],1)) # 2D array}

    #2 Scaling the data
    scaler=RobustScaler()
    new_train_X=scaler.fit_transform(new_train_X) 
    new_test_X=scaler.transform(new_test_X)
    
    #3 Create a new model with the updated feature set
    new_model=Sequential() 
    new_model.add(Dense(50,input_dim=len(new_features),activation='relu',kernel_regularizer=l2(0.01))) # one hidden layer
    new_model.add(Dense(1,activation='sigmoid',kernel_regularizer=l2(0.01))) #output layer
        
    #4 Compile the new model
    new_model.compile(loss='binary_crossentropy',optimizer=SGD(momentum=0.9),metrics=['accuracy'])
    
    print(feature)
    
    #5 Train the new model
    new_model.fit(new_train_X,new_train_Y,epochs=150,batch_size=len(new_train_X),validation_data=(new_test_X,new_test_Y))
    
    #6 Evaluate the new model
    testPredict_probs_new=new_model.predict(new_test_X)
    threshold = 0.5  # Adjust this threshold as needed
    y_new_pred = (testPredict_probs_new > threshold).astype(int)
    new_accuracy = accuracy_score(new_test_Y,y_new_pred)
    accuracy_store.append(new_accuracy)
    
    # Update the baseline feature set if the accuracy score improved
    if new_accuracy> base_accuracy:
        base_features = new_features
        base_accuracy = new_accuracy
        optimal_features.append(new_features)
    
    # Check for convergence
    #if len(base_features) == random_forest_data.iloc[:,:-1].shape[1]:
     #   break
        
# Stop the timer and calculate the elapsed time
end_time = time.time()
training_time = end_time - start_time

# %%
print("Simulation ended",training_time)
print("Best feature set:", base_features)
print("Best accuracy score:", base_accuracy)

# %%
accuracy_store

# %%
common_accuracy_store=accuracy_store
common_base_features=base_features
common_base_accuracy=base_accuracy
common_optimal_features=optimal_features

# %store common_accuracy_store
# %store common_base_features
# %store common_base_accuracy
# %store common_optimal_features

# %%
len(new_train_X)

# %%
type(new_data)
